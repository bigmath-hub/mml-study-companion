# %%
import numpy as np 

def solve_linear_system():
    """
    Solves the system of linear equation from chapter 2.1:
    4x_1 + 4x_2 = 5
    2x_1 - 4x_2 = 1
    """

    # 1. Define the coefficient matrix A
    A = np.array((
        [4, 4],
        [2, -4]
    ))

    #2. Define the dependent variable vector b
